# %% [markdown]
# #**EXTRACCIÓN DE CARACTERISTICAS**

# %% [markdown]
# # Descripción de Librerías Utilizadas
#
# Este proyecto utiliza las siguientes librerías para el procesamiento de imágenes de variedades nativas de papas:
#
# 1. **os**: Permite la interacción con el sistema operativo para manipular rutas de archivos y directorios.
#
# 2. **cv2 (OpenCV)**: Proporciona herramientas avanzadas de visión por computadora, facilitando la lectura, el procesamiento y la segmentación de imágenes.
#
# 3. **numpy**: Ofrece soporte para operaciones matemáticas y manipulación de arreglos, fundamental para el manejo eficiente de datos en el proyecto.
#
# 4. **pandas**: Se utiliza para la manipulación y análisis de datos, permitiendo trabajar con DataFrames y facilitar la exportación de resultados a archivos CSV.
#
# 5. **skimage.feature (Scikit-Image)**: Proporciona funciones para la extracción de características de textura a través de la matriz de co-ocurrencia de niveles de gris (GLCM).
#
# 6. **mahotas**: Incluye algoritmos de procesamiento de imágenes y extracción de características, como los momentos de Haralick, que son útiles para describir la textura de las imágenes.
#
# 7. **pathlib**: Facilita la manipulación de rutas de archivos de manera orientada a objetos, mejorando la legibilidad y mantenimiento del código.
#
# 8. **matplotlib.pyplot**: Utilizada para la visualización de imágenes y gráficos, permite presentar visualmente los resultados del procesamiento.
#
# 9. **sklearn.cluster (KMeans)**: Proporciona la implementación del algoritmo K-means para la agrupación de colores en las imágenes, permitiendo identificar colores predominantes en las muestras.
#
# Estas librerías son esenciales para llevar a cabo las tareas de procesamiento y análisis de imágenes, así como para la organización y visualización de los resultados obtenidos.

# %% [markdown]
# # Características Extraídas de las Imágenes de Papas Nativas
#
# El siguiente código procesa imágenes de papas nativas y extrae las siguientes características:
#
# ## 1. Características de Forma
# - **Área:** Área del contorno de la papa.
# - **Perímetro:** Longitud del contorno.
# - **Relación de Aspecto:** Proporción entre el ancho y la altura del contorno.
# - **Extent:** Relación entre el área del contorno y el área del rectángulo delimitador.
# - **Circularidad:** Medida de cuán cerca está la forma del contorno de ser un círculo perfecto.
# - **Momentos de Hu:** Siete momentos de Hu, invariantes a escala, rotación y traslación.
#
# ## 2. Características de Color
# Para cada uno de los espacios de color (BGR, HSV y LAB):
# - **Media:** Promedio de los valores de píxeles.
# - **Desviación estándar:** Medida de la dispersión de los valores de píxeles.
# - **Percentil 25:** Valor en el que el 25% de los píxeles tienen un valor menor.
# - **Percentil 75:** Valor en el que el 75% de los píxeles tienen un valor menor.
#
# ## 3. Características de Textura
# - **GLCM (Matriz de Co-ocurrencia de Niveles de Gris):**
#   - **Contraste**
#   - **Disimilitud**
#   - **Homogeneidad**
#   - **Energía**
#   - **Correlación**
# - **Características de Haralick:** 13 características relacionadas con la textura.
#
# ## 4. Color Predominante
# - **KMeans:** Extrae el color predominante de la imagen, devolviendo el color promedio de los clusters encontrados.
#
# ## Resumen de la Salida
# Cada imagen procesada produce un vector de características que incluye:
# - **12 características de forma.**
# - **36 características de color** (3 espacios de color × 4 métricas por espacio).
# - **5 características de textura** (GLCM).
# - **13 características de textura de Haralick.**
# - **3 características de color predominante** (R, G, B).
#
# En total, se generan **66 características por imagen**, además de su etiqueta y nombre de imagen que se almacenan en un DataFrame y se guardan en un archivo CSV.

# %%
# !pip install scikit-image mahotas opencv-python-headless
# Out:
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.24.0)
# Collecting mahotas
#   Downloading mahotas-1.4.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (0.4)
# Downloading mahotas-1.4.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 37.6 MB/s eta 0:00:00
# Installing collected packages: mahotas
# Successfully installed mahotas-1.4.18

# %%
# !pip install opencv-python numpy pandas scikit-image mahotas matplotlib
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.24.0)
# Requirement already satisfied: mahotas in /usr/local/lib/python3.10/dist-packages (1.4.18)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
import pandas as pd
from skimage.feature import graycomatrix, graycoprops
import mahotas
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from google.colab import drive

class ProcesadorPapaNativa:
    def __init__(self):
        self.caracteristicas = []
        self.etiquetas = []
        self.nombres_imagenes = []
        self.imagenes_fallidas = []

    def visualizar_procesamiento(self, imagen, binaria, contorno, mascara):
        fig, axes = plt.subplots(2, 2, figsize=(12, 12))

        axes[0, 0].imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))
        axes[0, 0].set_title('Imagen Original')

        axes[0, 1].imshow(binaria, cmap='gray')
        axes[0, 1].set_title('Segmentación')

        img_contorno = imagen.copy()
        cv2.drawContours(img_contorno, [contorno], -1, (0, 255, 0), 2)
        axes[1, 0].imshow(cv2.cvtColor(img_contorno, cv2.COLOR_BGR2RGB))
        axes[1, 0].set_title('Contorno Detectado')

        axes[1, 1].imshow(mascara, cmap='gray')
        axes[1, 1].set_title('Máscara')

        for ax in axes.flat:
            ax.axis('off')

        plt.tight_layout()
        plt.show()

    def preprocesar_imagen(self, imagen):
        max_dim = 800
        height, width = imagen.shape[:2]
        if max(height, width) > max_dim:
            scale = max_dim / max(height, width)
            imagen = cv2.resize(imagen, None, fx=scale, fy=scale)

        imagen = cv2.GaussianBlur(imagen, (5, 5), 0)
        return imagen

    def extraer_caracteristicas_forma(self, contorno):
        area = cv2.contourArea(contorno)
        perimetro = cv2.arcLength(contorno, True)

        x, y, w, h = cv2.boundingRect(contorno)
        aspect_ratio = float(w) / h
        extent = float(area) / (w * h) if (w * h) > 0 else 0
        circularidad = 4 * np.pi * area / (perimetro * perimetro) if perimetro > 0 else 0

        momentos = cv2.moments(contorno)
        hu_moments = cv2.HuMoments(momentos).flatten()
        hu_moments = -np.sign(hu_moments) * np.log10(np.abs(hu_moments) + 1e-10)

        return [area, perimetro, aspect_ratio, extent, circularidad] + list(hu_moments)

    def extraer_caracteristicas_color(self, imagen, mascara):
        hsv = cv2.cvtColor(imagen, cv2.COLOR_BGR2HSV)
        lab = cv2.cvtColor(imagen, cv2.COLOR_BGR2LAB)

        caracteristicas_color = []

        for espacio in [imagen, hsv, lab]:
            for i in range(3):
                canal = espacio[:, :, i]
                pixels = canal[mascara > 0]

                if len(pixels) > 0:
                    caracteristicas_color.extend([
                        np.mean(pixels),
                        np.std(pixels),
                        np.percentile(pixels, 25),
                        np.percentile(pixels, 75)
                    ])
                else:
                    caracteristicas_color.extend([0, 0, 0, 0])

        return caracteristicas_color

    def extraer_caracteristicas_textura(self, imagen_gris, mascara):
        roi = imagen_gris.copy()
        roi[mascara == 0] = 0

        distancias = [1]
        angulos = [0, np.pi / 4, np.pi / 2, 3 * np.pi / 4]

        glcm = graycomatrix(roi, distances=distancias, angles=angulos,
                            levels=256, symmetric=True, normed=True)

        propiedades = ['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation']

        caracteristicas_glcm = []
        for prop in propiedades:
            valor = graycoprops(glcm, prop).mean()
            caracteristicas_glcm.append(valor)

        haralick = mahotas.features.haralick(roi).mean(axis=0)[:13]

        return list(caracteristicas_glcm) + list(haralick)

    def extraer_color_predominante(self, imagen, n_colores=5):
        image = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
        pixels = image.reshape(-1, 3)

        kmeans = KMeans(n_clusters=n_colores)
        kmeans.fit(pixels)

        colores = kmeans.cluster_centers_.astype(int)

        return colores.mean(axis=0)  # Devolver el color promedio

    def contar_ojos(self, imagen, mascara):
        gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
        _, binaria = cv2.threshold(gris, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
        contornos, _ = cv2.findContours(binaria, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        eye_count = 0
        for contorno in contornos:
            if cv2.contourArea(contorno) > 100:  # Ajusta este valor según sea necesario
                eye_count += 1

        return eye_count

    def procesar_imagen(self, ruta_imagen, visualizar=False):
        try:
            imagen = cv2.imread(ruta_imagen)
            if imagen is None:
                raise ValueError(f"No se pudo leer la imagen: {ruta_imagen}")

            imagen = self.preprocesar_imagen(imagen)

            gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
            _, binaria = cv2.threshold(gris, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

            contornos, _ = cv2.findContours(binaria, cv2.RETR_EXTERNAL,
                                           cv2.CHAIN_APPROX_SIMPLE)

            if not contornos:
                raise ValueError(f"No se encontraron contornos en: {ruta_imagen}")

            contorno = max(contornos, key=cv2.contourArea)

            mascara = np.zeros(gris.shape, dtype=np.uint8)
            cv2.drawContours(mascara, [contorno], -1, 255, -1)

            if visualizar:
                self.visualizar_procesamiento(imagen, binaria, contorno, mascara)

            caract_forma = self.extraer_caracteristicas_forma(contorno)
            caract_color = self.extraer_caracteristicas_color(imagen, mascara)
            caract_textura = self.extraer_caracteristicas_textura(gris, mascara)

            color_predominante = self.extraer_color_predominante(imagen)
            num_ojos = self.contar_ojos(imagen, mascara)

            print(f"Características de forma: {len(caract_forma)}, color: {len(caract_color)}, textura: {len(caract_textura)}")

            return caract_forma + caract_color + caract_textura + list(color_predominante) + [num_ojos]

        except Exception as e:
            print(f"Error procesando {ruta_imagen}: {str(e)}")
            self.imagenes_fallidas.append((ruta_imagen, str(e)))
            return None

    def procesar_dataset(self, directorio_base, visualizar_primeras=False):
        print(f"Iniciando procesamiento del dataset en: {directorio_base}")
        total_procesadas = 0

        # Lista de carpetas (números del 1 al 88)
        carpetas = range(1, 89)

        for i in carpetas:
            ruta_carpeta = os.path.join(directorio_base, str(i))

            # Verificar si la carpeta existe
            if not os.path.exists(ruta_carpeta):
                print(f'Carpeta no encontrada: {ruta_carpeta}, se omite.')
                continue  # Omitir esta carpeta y pasar a la siguiente

            print(f"Procesando carpeta: {i}")
            for imagen_path in Path(ruta_carpeta).glob("*.jpg"):
                print(f"Procesando imagen: {imagen_path.name}")
                visualizar = visualizar_primeras and total_procesadas < 2

                vector = self.procesar_imagen(str(imagen_path), visualizar)

                if vector is not None:
                    expected_length = 66 + 3 + 1  # 12 (forma) + 36 (color) + 18 (textura) + 3 (color predominante) + 1 (número de ojos)

                    if len(vector) == expected_length:
                        self.caracteristicas.append(vector)
                        self.etiquetas.append(imagen_path.stem)
                        self.nombres_imagenes.append(imagen_path.name)
                        total_procesadas += 1
                    else:
                        print(f"Vector de características de tamaño inesperado para {imagen_path.name}: {len(vector)}")

                if total_procesadas % 10 == 0 and total_procesadas > 0:
                    print(f"Procesadas {total_procesadas} imágenes...")

        print(f"Total de imágenes procesadas: {total_procesadas}")

        if not self.caracteristicas:
            print("No hay características para guardar.")
            return

        # Guardar características en un DataFrame
        nombres_columnas = (
            ['area', 'perimetro', 'aspect_ratio', 'extent', 'circularidad'] +
            [f'hu_moment_{i+1}' for i in range(7)] +
            ['media_r', 'std_r', 'percentil_25_r', 'percentil_75_r'] * 9 +
            [f'glcm_{prop}' for prop in ['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation']] +
            [f'haralick_{i+1}' for i in range(13)] +
            ['color_predominante_r', 'color_predominante_g', 'color_predominante_b', 'num_ojos']
        )

        df_caracteristicas = pd.DataFrame(self.caracteristicas, columns=nombres_columnas)
        df_caracteristicas['etiqueta'] = self.etiquetas
        df_caracteristicas['nombre_imagen'] = self.nombres_imagenes

        df_caracteristicas.to_csv('caracteristicas_papa_nativa(3).csv', index=False)
        print("Características guardadas en 'caracteristicas_papa_nativa(3).csv'")

# %%
if __name__ == "__main__":
    # Montar Google Drive
    drive.mount('/content/drive')

    procesador = ProcesadorPapaNativa()

    # Ruta a la carpeta que contiene las subcarpetas
    ruta_base = '/content/drive/MyDrive/imagenes-Papas/imagenes/'

    # Procesar el dataset en la ruta base
    procesador.procesar_dataset(ruta_base, visualizar_primeras=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Iniciando procesamiento del dataset en: /content/drive/MyDrive/imagenes-Papas/imagenes/
# Procesando carpeta: 1
# Procesando imagen: 1 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 1 (2).jpg
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Procesando imagen: 42 (59).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 42 (60).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 42 (61).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 42 (62).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 42 (63).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 42 (64).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 42 (65).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 42 (66).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2510 imágenes...
# Procesando imagen: 42 (67).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 42 (68).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 42 (69).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando carpeta: 43
# Procesando imagen: 43 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (2).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (3).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (4).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (5).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (6).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (7).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2520 imágenes...
# Procesando imagen: 43 (8).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (9).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (10).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (11).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (12).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (13).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (14).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (15).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (16).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (17).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2530 imágenes...
# Procesando imagen: 43 (18).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (19).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (20).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (21).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (22).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (23).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (24).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (25).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (26).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (27).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2540 imágenes...
# Procesando imagen: 43 (28).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (29).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (30).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (31).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (32).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (33).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (34).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (35).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (36).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (37).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2550 imágenes...
# Procesando imagen: 43 (38).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (39).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (40).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (41).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (42).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (43).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (44).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (45).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (46).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (47).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2560 imágenes...
# Procesando imagen: 43 (48).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (49).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (50).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (51).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (52).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (53).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (54).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (55).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (56).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (57).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2570 imágenes...
# Procesando imagen: 43 (58).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 43 (59).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando carpeta: 44
# Procesando imagen: 44 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (2).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (3).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (4).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (5).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (6).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (7).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (8).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2580 imágenes...
# Procesando imagen: 44 (9).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (10).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (11).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (12).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (13).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (14).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (15).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (16).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (17).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (18).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2590 imágenes...
# Procesando imagen: 44 (19).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (20).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (21).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (22).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (23).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (24).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (25).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (26).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (27).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (28).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2600 imágenes...
# Procesando imagen: 44 (29).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (30).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (31).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (32).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (33).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (34).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (35).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (36).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (37).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (38).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2610 imágenes...
# Procesando imagen: 44 (39).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (40).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (41).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (42).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (43).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (44).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (45).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (46).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (47).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (48).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2620 imágenes...
# Procesando imagen: 44 (49).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (50).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (51).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (52).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (53).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (54).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (55).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (56).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (57).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (58).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2630 imágenes...
# Procesando imagen: 44 (59).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (60).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (61).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (62).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (63).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (64).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (65).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 44 (66).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando carpeta: 45
# Procesando imagen: 45 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (2).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2640 imágenes...
# Procesando imagen: 45 (3).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (4).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (5).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (6).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (7).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (8).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (9).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (10).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (11).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (12).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2650 imágenes...
# Procesando imagen: 45 (13).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (14).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (15).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (16).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (17).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (18).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (19).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (20).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (21).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (22).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2660 imágenes...
# Procesando imagen: 45 (23).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (24).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (25).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (26).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (27).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (28).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (29).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (30).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (31).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (32).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2670 imágenes...
# Procesando imagen: 45 (33).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (34).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (35).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (36).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (37).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (38).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (39).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (40).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (41).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (42).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2680 imágenes...
# Procesando imagen: 45 (43).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (44).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (45).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (46).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (47).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (48).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (49).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 45 (50).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando carpeta: 46
# Procesando imagen: 46 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (2).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2690 imágenes...
# Procesando imagen: 46 (3).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (4).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (5).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (6).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (7).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (8).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (9).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (10).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (11).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (12).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2700 imágenes...
# Procesando imagen: 46 (13).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (14).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (15).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (16).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (17).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (18).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (19).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (20).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (21).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (22).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2710 imágenes...
# Procesando imagen: 46 (23).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (24).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (25).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (26).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (27).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (28).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (29).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (30).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (31).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (32).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2720 imágenes...
# Procesando imagen: 46 (33).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (34).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (35).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (36).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (37).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (38).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (39).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (40).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (41).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (42).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2730 imágenes...
# Procesando imagen: 46 (43).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (44).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (45).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (46).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (47).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (48).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (49).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (50).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (51).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 46 (52).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2740 imágenes...
# Procesando imagen: 46 (53).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando carpeta: 47
# Procesando imagen: 47 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (2).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (3).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (4).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (5).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (6).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (7).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (8).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (9).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2750 imágenes...
# Procesando imagen: 47 (10).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (11).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (12).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (13).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (14).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (15).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (16).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (17).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (18).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (19).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2760 imágenes...
# Procesando imagen: 47 (20).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (21).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (22).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (23).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (24).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (25).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (26).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (27).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (28).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (29).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2770 imágenes...
# Procesando imagen: 47 (30).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (31).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (32).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (33).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (34).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (35).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (36).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (37).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (38).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (39).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2780 imágenes...
# Procesando imagen: 47 (40).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (41).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (42).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (43).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (44).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (45).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (46).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (47).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (48).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (49).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2790 imágenes...
# Procesando imagen: 47 (50).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (51).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (52).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (53).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (54).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (55).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (56).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (57).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (58).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (59).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2800 imágenes...
# Procesando imagen: 47 (60).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (61).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (62).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (63).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (64).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 47 (65).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando carpeta: 48
# Procesando imagen: 48 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (2).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (3).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (4).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2810 imágenes...
# Procesando imagen: 48 (5).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (6).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (7).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (8).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (9).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (10).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (11).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (12).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (13).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (14).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2820 imágenes...
# Procesando imagen: 48 (15).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (16).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (17).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (18).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (19).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (20).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (21).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (22).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (23).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (24).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2830 imágenes...
# Procesando imagen: 48 (25).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (26).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (27).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (28).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (29).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (30).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (31).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (32).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (33).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (34).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2840 imágenes...
# Procesando imagen: 48 (35).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (36).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (37).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (38).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (39).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (40).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (41).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (42).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (43).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (44).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2850 imágenes...
# Procesando imagen: 48 (45).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (46).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (47).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (48).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (49).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (50).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (51).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 48 (52).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando carpeta: 49
# Procesando imagen: 49 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (2).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2860 imágenes...
# Procesando imagen: 49 (3).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (4).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (5).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (6).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (7).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (8).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (9).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (10).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (11).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (12).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2870 imágenes...
# Procesando imagen: 49 (13).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (14).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (15).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (16).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (17).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (18).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (19).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (20).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (21).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (22).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2880 imágenes...
# Procesando imagen: 49 (23).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (24).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (25).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (26).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (27).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (28).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (29).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (30).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (31).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (32).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2890 imágenes...
# Procesando imagen: 49 (33).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (34).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (35).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (36).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (37).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (38).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (39).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (40).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (41).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (42).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2900 imágenes...
# Procesando imagen: 49 (43).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (44).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (45).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (46).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (47).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (48).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (49).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (50).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (51).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (52).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2910 imágenes...
# Procesando imagen: 49 (53).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (54).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (55).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (56).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (57).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (58).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (59).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (60).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (61).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (62).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2920 imágenes...
# Procesando imagen: 49 (63).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (64).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (65).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (66).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (67).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (68).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (69).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (70).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (71).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 49 (72).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2930 imágenes...
# Procesando imagen: 49 (73).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando carpeta: 50
# Procesando imagen: 50 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (2).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (3).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (4).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (5).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (6).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (7).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (8).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (9).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2940 imágenes...
# Procesando imagen: 50 (10).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (11).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (12).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (13).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (14).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (15).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (16).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (17).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (18).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (19).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2950 imágenes...
# Procesando imagen: 50 (20).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (21).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (22).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (23).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (24).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (25).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (26).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (27).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (28).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (29).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2960 imágenes...
# Procesando imagen: 50 (30).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (31).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (32).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (33).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (34).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (35).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (36).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (37).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (38).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (39).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2970 imágenes...
# Procesando imagen: 50 (40).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (41).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (42).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (43).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (44).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (45).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (46).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (47).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (48).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (49).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2980 imágenes...
# Procesando imagen: 50 (50).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (51).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (53).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (52).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (54).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (55).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (56).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (57).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (58).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (59).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 2990 imágenes...
# Procesando imagen: 50 (60).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 50 (61).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando carpeta: 51
# Procesando imagen: 51 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (2).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (3).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (4).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (5).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (6).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (7).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (8).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 3000 imágenes...
# Procesando imagen: 51 (9).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (10).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (11).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (12).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (13).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (14).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (15).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (16).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (17).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (18).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 3010 imágenes...
# Procesando imagen: 51 (19).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (20).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (21).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (22).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (23).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (24).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (25).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (26).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (27).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (28).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 3020 imágenes...
# Procesando imagen: 51 (29).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (30).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (31).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (32).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (33).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (34).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (35).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (36).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (37).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (38).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 3030 imágenes...
# Procesando imagen: 51 (39).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (40).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (41).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (42).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (43).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (44).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (45).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (46).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (47).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (48).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 3040 imágenes...
# Procesando imagen: 51 (49).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (50).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (51).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (52).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (53).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (54).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (55).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (56).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 51 (57).jpg
# Características de forma: 12, color: 36, textura: 18
# ...
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 81 (86).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 81 (87).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 81 (88).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 81 (89).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 81 (90).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 81 (91).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 81 (92).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 81 (93).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4690 imágenes...
# Procesando imagen: 81 (94).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 81 (95).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 81 (96).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 81 (97).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 81 (98).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando carpeta: 82
# Procesando imagen: 82 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (2).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (3).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (4).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (5).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4700 imágenes...
# Procesando imagen: 82 (6).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (7).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (8).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (9).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (10).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (11).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (12).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (13).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (14).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (15).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4710 imágenes...
# Procesando imagen: 82 (16).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (17).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (18).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (19).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (20).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (21).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (22).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (23).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (24).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (25).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4720 imágenes...
# Procesando imagen: 82 (26).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (27).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (28).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (29).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (30).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (31).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (32).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (33).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (34).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (35).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4730 imágenes...
# Procesando imagen: 82 (36).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (37).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (38).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (39).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (40).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (41).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (42).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (43).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (44).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (45).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4740 imágenes...
# Procesando imagen: 82 (46).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (47).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (48).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (49).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (50).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (51).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (52).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (53).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (54).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (55).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4750 imágenes...
# Procesando imagen: 82 (56).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (57).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (58).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (59).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (60).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (61).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (62).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (63).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (64).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (65).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4760 imágenes...
# Procesando imagen: 82 (66).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (67).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (68).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (69).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (70).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (71).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (72).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 82 (73).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando carpeta: 83
# Procesando imagen: 83 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (2).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4770 imágenes...
# Procesando imagen: 83 (3).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (4).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (5).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (6).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (7).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (8).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (9).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (10).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (11).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (12).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4780 imágenes...
# Procesando imagen: 83 (13).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (14).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (15).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (16).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (17).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (18).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (19).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (20).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (21).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (22).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4790 imágenes...
# Procesando imagen: 83 (23).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (24).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (25).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (26).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (27).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (28).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (29).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (30).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (31).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (32).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4800 imágenes...
# Procesando imagen: 83 (33).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (34).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (35).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (36).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (37).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (38).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (39).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (40).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (41).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (42).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4810 imágenes...
# Procesando imagen: 83 (43).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (44).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (45).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 83 (46).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando carpeta: 84
# Procesando imagen: 84 (1).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (2).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (3).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (4).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (5).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (6).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4820 imágenes...
# Procesando imagen: 84 (7).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (8).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (9).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (10).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (11).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (12).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (13).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (14).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (15).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (16).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4830 imágenes...
# Procesando imagen: 84 (17).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (18).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (19).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (20).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (21).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (22).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (23).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (24).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (25).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (26).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4840 imágenes...
# Procesando imagen: 84 (27).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (28).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (29).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (30).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (31).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (32).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (33).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (34).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (35).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (36).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4850 imágenes...
# Procesando imagen: 84 (37).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (38).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (39).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (40).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (41).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (42).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (43).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (44).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (45).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesando imagen: 84 (46).jpg
# Características de forma: 12, color: 36, textura: 18
# Procesadas 4860 imágenes...
# Carpeta no encontrada: /content/drive/MyDrive/imagenes-Papas/imagenes/85, se omite.
# Carpeta no encontrada: /content/drive/MyDrive/imagenes-Papas/imagenes/86, se omite.
# Carpeta no encontrada: /content/drive/MyDrive/imagenes-Papas/imagenes/87, se omite.
# Carpeta no encontrada: /content/drive/MyDrive/imagenes-Papas/imagenes/88, se omite.
# Total de imágenes procesadas: 4860
# Características guardadas en 'caracteristicas_papa_nativa(3).csv'
